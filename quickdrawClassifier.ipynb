# %% [markdown]
# # Intro to Computer Vision
# In this notebook you will use the [quickdraw](https://quickdraw.withgoogle.com/data) dataset to build a simple image recongnition neural net.
#
# We will be using matplotlib for this assignment so start with installing it via pip.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras import layers
import plotly.express as px
from sklearn.preprocessing import LabelEncoder
import numpy as np
import tensorflow as tf
import random
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 1: Data
#
# Quickdraw supports A LOT of images. Rather than training on all 50 million, we will start with just a few.
# Your model should train on at least 5 categories of drawings.
# This will be more fun if they look similar to each other.
#
# Go to [quickdraw](https://quickdraw.withgoogle.com/data) and select at least 5 categories to use for your model. These are stored in a Google Cloud storage bucket called quickdraw_dataset.
#
# Load each of your categories by these steps:
#
# 1. ` pip install gsutil`
#
# 2.  `gsutil -m cp 'gs://quickdraw_dataset/full/numpy_bitmap/<your category>.npy' .`
#
#
# Do step 2 once per category.
#
# *You will need to do this both locally and in your gcloud vm. (they are too big to push to github)

# %% [markdown]
# ## Load Your Data
#
# Your data will be in a .npy format (numpy array). We will load it differently this time: for example
#
# `data_airplanes = np.load("airplane.npy")`

# %%
# Helper function to show images from your dataset
def show_image(data):
    index = random.randint(0, len(data)-1)
    img2d = data[index].reshape(28, 28)
    plt.figure()
    plt.imshow(img2d)
    plt.colorbar()
    plt.grid(False)
    plt.show()

# %%
# Load your first cateogry of images
data_apple = np.load("apple.npy")

# %%
# Now use the function above to show an image from your data
show_image(data_apple)

# %%
# Now load your second category of images
data_blackberry = np.load("blackberry.npy")

# %%
# visualize your second category of images
show_image(data_blackberry)

# %%
# Now load your third category of images
data_clock = np.load("clock.npy")

# %%
# visualize your third category of images
show_image(data_clock)

# %%
# Now load your 4th category of images
data_cookie = np.load("cookie.npy")

# %%
# visualize your 4th category of images
show_image(data_cookie)

# %%
# Now load your 5th category of images
data_toilet = np.load("toilet.npy")

# %%
# visualize your 5th category of images
show_image(data_toilet)

# %% [markdown]
# ## Preprocess your data
#
# Now it's time to define X and y. We want our X and y data to include ALL of the categories you loaded above.
#
# You can combine np.arrays together using something like `np.vstack`.

# %%
# define X by combining all loaded data from above
X = np.vstack([data_toilet, data_cookie, data_clock, data_blackberry, data_apple])

# %%
# verify the X was defined correctly
assert X.shape[1] == 784
assert X.shape[0] >= 550000

# %% [markdown]
# Now it's time to define y. Recall that y is an array of "correct labels" for our data. For example, ['airplane', 'airplane', 'cat', 'bird', ....]
#
#
# In the above step you created an array of images stored in X of 5 different categories. Now, create an array of labels to match those images.

# %%
# define y by creating an array of labels that match X
y = np.concatenate([
    np.full(len(data_toilet),0),
    np.full(len(data_cookie),1),
    np.full(len(data_clock),2),
    np.full(len(data_blackberry), 3),
    np.full(len(data_apple),4)
])

# %%
# verify that y is the same length as X
assert len(y) == len(X)

# %% [markdown]
# ## Split your data
#
# Split your data is 80 training/ 20 testing as usual.

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Define your model
#
# Now define your neural network using tensorflow.

# %%
# Define your model with the correct input shape and appropriate layers
model = tf.keras.models.Sequential([
   
 tf.keras.layers.Dense(1024, input_shape=[X_train.shape[1]]),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(200, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')   



])

# %%
# Compile your model
lr = 0.001



model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr), 
    metrics =['accuracy']
)

# %% [markdown]
# ## Train your model locally
#
# Train your model.

# %%
# Fit your model 
history = model.fit(X_train, y_train, validation_data =(X_test, y_test), epochs=100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 2
#       1 # Fit your model
# ----> 2 history = model.fit(X_train, y_train, validation_data =(X_test, y_test), epochs=100)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:360, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     353     (
#     354         val_x,
#     355         val_y,
#     356         val_sample_weight,
#     357     ) = data_adapter_utils.unpack_x_y_sample_weight(validation_data)
#     359 # Create an iterator that yields batches for one epoch.
# --> 360 epoch_iterator = TFEpochIterator(
#     361     x=x,
#     362     y=y,
#     363     sample_weight=sample_weight,
#     364     batch_size=batch_size,
#     365     steps_per_epoch=steps_per_epoch,
#     366     shuffle=shuffle,
#     367     class_weight=class_weight,
#     368     distribute_strategy=self.distribute_strategy,
#     369     steps_per_execution=self.steps_per_execution,
#     370 )
#     372 self._maybe_symbolic_build(iterator=epoch_iterator)
#     373 epoch_iterator.reset()
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:750, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     748 super().__init__(*args, **kwargs)
#     749 self._distribute_strategy = distribute_strategy
# --> 750 dataset = self.data_adapter.get_tf_dataset()
#     751 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     752     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     753         dataset
#     754     )
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:237, in ArrayDataAdapter.get_tf_dataset(self)
#     234 if shuffle == "batch":
#     235     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 237 dataset = slice_inputs(indices_dataset, self._inputs)
#     239 options = tf.data.Options()
#     240 options.experimental_distribute.auto_shard_policy = (
#     241     tf.data.experimental.AutoShardPolicy.DATA
#     242 )
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:199, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     193 inputs = array_slicing.convert_to_sliceable(
#     194     self._inputs, target_backend="tensorflow"
#     195 )
#     196 inputs = tree.lists_to_tuples(inputs)
#     198 dataset = tf.data.Dataset.zip(
# --> 199     (indices_dataset, tf.data.Dataset.from_tensors(inputs).repeat())
#     200 )
#     202 def grab_batch(i, data):
#     203     def grab_one(x):
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/data/ops/dataset_ops.py:741, in DatasetV2.from_tensors(tensors, name)
#     737 # Loaded lazily due to a circular dependency (dataset_ops ->
#     738 # from_tensors_op -> dataset_ops).
#     739 # pylint: disable=g-import-not-at-top,protected-access
#     740 from tensorflow.python.data.ops import from_tensors_op
# --> 741 return from_tensors_op._from_tensors(tensors, name)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/data/ops/from_tensors_op.py:23, in _from_tensors(tensors, name)
#      22 def _from_tensors(tensors, name):  # pylint: disable=unused-private-name
# ---> 23   return _TensorDataset(tensors, name)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/data/ops/from_tensors_op.py:31, in _TensorDataset.__init__(self, element, name)
#      29 def __init__(self, element, name=None):
#      30   """See `tf.data.Dataset.from_tensors` for details."""
# ---> 31   element = structure.normalize_element(element)
#      32   self._structure = structure.type_spec_from_value(element)
#      33   self._tensors = structure.to_tensor_list(self._structure, element)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/data/util/structure.py:134, in normalize_element(element, element_signature)
#     131       else:
#     132         dtype = getattr(spec, "dtype", None)
#     133         normalized_components.append(
# --> 134             ops.convert_to_tensor(t, name="component_%d" % i, dtype=dtype))
#     135 return nest.pack_sequence_as(pack_as, normalized_components)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:757, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     755 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     756 preferred_dtype = preferred_dtype or dtype_hint
# --> 757 return tensor_conversion_registry.convert(
#     758     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     759 )
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)    230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/framework/constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)    274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287     with trace.Trace("tf.constant"):
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:301, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     297 def _constant_eager_impl(
#     298     ctx, value, dtype, shape, verify_shape
#     299 ) -> ops._EagerTensorBase:
#     300   """Creates a constant on the current device."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# # Train your model on gcloud
#
# Your model likely is a bit slow... move it to the Gcloud gpu. Since we can't run notebooks in gcloud, you can convert it to a python file first by running:
#
# `jupytext --to py quickdrawClassifier.ipynb`
#
# Then push the generated quickdrawClassifier.py file to github and then pull it down to your gcloud laptop to run.
